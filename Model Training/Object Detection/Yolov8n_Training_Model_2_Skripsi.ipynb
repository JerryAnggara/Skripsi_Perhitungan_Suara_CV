# %% [markdown]
# <a href="https://colab.research.google.com/github/JerryAnggara/Skripsi_Perhitungan_Suara_CV/blob/main/Model%20Training/Object%20Detection/Yolov8n_Training_Model_2_Skripsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Skripsi: Model Training YoloV8n** </br>
# Source Dataset: https://app.roboflow.com/skripsi-2025-dnrgq/skripsi2025-pre1/2

# %%
# !nvidia-smi
# Out:
# Thu May 22 13:45:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.142 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.6/112.6 GB disk)

# %%
import os
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7e1kBC6srdwaqLDGRSP4")
project = rf.workspace("skripsi-2025-dnrgq").project("skripsi2025-pre1")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.1.64)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.4.26)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Requirement already satisfied: pillow-heif>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Skripsi2025---Pre1-2/data.yaml epochs=50 imgsz=640 batch=32
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 115MB/s]
# Ultralytics 8.3.142 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Skripsi2025---Pre1-2/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 22.9MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 129 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 95.3MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1128.1±464.1 MB/s, size: 44.5 KB)
# train: Scanning /content/Skripsi2025---Pre1-2/train/labels... 1244 images, 0 backgrounds, 0 corrupt: 100% 1244/1244 [00:00<00:00, 2424.45it/s]
# train: New cache created: /content/Skripsi2025---Pre1-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 754.5±409.2 MB/s, size: 50.0 KB)
# val: Scanning /content/Skripsi2025---Pre1-2/valid/labels... 109 images, 0 backgrounds, 0 corrupt: 100% 109/109 [00:00<00:00, 1726.68it/s]
# val: New cache created: /content/Skripsi2025---Pre1-2/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.17G     0.9605       2.12      1.128        218        640: 100% 39/39 [00:23<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.21s/it]
#                    all        109        447      0.954      0.654      0.746      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.95G     0.5733     0.6975     0.8742        191        640: 100% 39/39 [00:18<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.24it/s]
#                    all        109        447      0.999      0.749      0.801      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.96G      0.562     0.5941      0.872        186        640: 100% 39/39 [00:19<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.13it/s]
#                    all        109        447      0.979      0.855      0.943      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.98G     0.5616     0.5478     0.8734        217        640: 100% 39/39 [00:19<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.34it/s]
#                    all        109        447      0.979      0.945      0.963      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         5G      0.535     0.4973     0.8678        155        640: 100% 39/39 [00:18<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.35it/s]
#                    all        109        447      0.973      0.954      0.968      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.02G     0.5285     0.4415     0.8659        212        640: 100% 39/39 [00:19<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.49it/s]
#                    all        109        447      0.959      0.899      0.959      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.03G     0.5262     0.4213      0.868        202        640: 100% 39/39 [00:19<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.44it/s]
#                    all        109        447      0.968      0.962      0.967      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.05G     0.5162     0.3888     0.8637        183        640: 100% 39/39 [00:18<00:00,  2.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.33it/s]
#                    all        109        447      0.975      0.956      0.971      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.07G     0.5169     0.3761      0.867        197        640: 100% 39/39 [00:19<00:00,  2.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.30it/s]
#                    all        109        447      0.977      0.965      0.971      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.08G     0.5029     0.3588     0.8611        206        640: 100% 39/39 [00:19<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.13it/s]
#                    all        109        447      0.981      0.953      0.978      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50       5.1G     0.5004     0.3439       0.86        151        640: 100% 39/39 [00:19<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.48it/s]
#                    all        109        447      0.971      0.937      0.973      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.12G     0.4984     0.3367     0.8575        202        640: 100% 39/39 [00:21<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.35it/s]
#                    all        109        447      0.964      0.948      0.963      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.13G     0.5045     0.3385     0.8638        164        640: 100% 39/39 [00:20<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.35it/s]
#                    all        109        447      0.981       0.96      0.978      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.15G     0.4939     0.3229     0.8598        214        640: 100% 39/39 [00:18<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.41it/s]
#                    all        109        447      0.967       0.95       0.97      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.17G     0.4923      0.315     0.8568        197        640: 100% 39/39 [00:20<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.26it/s]
#                    all        109        447      0.988      0.969      0.978      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.19G      0.488     0.3123      0.857        151        640: 100% 39/39 [00:20<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.24it/s]
#                    all        109        447       0.97       0.96      0.978      0.792
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50       5.2G     0.4927     0.3052     0.8584        179        640: 100% 39/39 [00:19<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.36it/s]
#                    all        109        447      0.986      0.965       0.98      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      5.22G     0.4799     0.2973     0.8566        187        640: 100% 39/39 [00:19<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.39it/s]
#                    all        109        447      0.983      0.969      0.977      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      5.24G     0.4738     0.2933      0.856        165        640: 100% 39/39 [00:20<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.75it/s]
#                    all        109        447       0.97       0.96      0.979      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.25G     0.4804     0.2938     0.8572        167        640: 100% 39/39 [00:19<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.17it/s]
#                    
00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.44it/s]
#                    all        109        447      0.985      0.977      0.985      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.77G     0.4075      0.188     0.8156        122        640: 100% 39/39 [00:19<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.30it/s]
#                    all        109        447      0.983      0.978      0.985      0.812
#
# 50 epochs completed in 0.304 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.142 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.22it/s]
#                    all        109        447      0.983      0.978      0.985      0.812
#           lubangCoblos         64        120      0.956      0.912      0.956      0.479
#                paslon1        109        109      0.992          1      0.995      0.904
#                paslon2        109        109      0.992          1      0.995      0.936
#                paslon3        109        109      0.992          1      0.995      0.928
# Speed: 0.3ms preprocess, 2.2ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=800)

# %%
Image(filename=f'/content/runs/detect/train/PR_curve.png', width=800)

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix_normalized.png', width=800)

# %%
Image(filename=f'/content/runs/detect/train/F1_curve.png', width=800)

# %%
Image(filename=f'/content/runs/detect/train/val_batch0_pred.jpg', width=800)

# %%
Image(filename=f'/content/runs/detect/train/val_batch1_pred.jpg', width=800)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/Skripsi2025---Pre1-2/data.yaml
# Out:
# Ultralytics 8.3.142 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2128.0±594.0 MB/s, size: 57.0 KB)
# val: Scanning /content/Skripsi2025---Pre1-2/valid/labels.cache... 109 images, 0 backgrounds, 0 corrupt: 100% 109/109 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.86it/s]
#                    all        109        447      0.985      0.978      0.986      0.813
#           lubangCoblos         64        120      0.965      0.913      0.958      0.485
#                paslon1        109        109      0.992          1      0.995      0.906
#                paslon2        109        109      0.992          1      0.995      0.936
#                paslon3        109        109      0.992          1      0.995      0.926
# Speed: 1.8ms preprocess, 10.4ms inference, 0.0ms loss, 5.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')

results = model.predict(source='/content/gdrive/MyDrive/Skripsi Colab/Datatest', conf=0.8, save=True)
# Out:
# image 1/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/16.jpg: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 42.9ms
# image 2/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/164.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.2ms
# image 3/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/165.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.0ms
# image 4/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/166.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.1ms
# image 5/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/167.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.0ms
# image 6/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/168.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 8.5ms
# image 7/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/169.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.0ms
# image 8/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/170.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 9/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/171.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 10/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/172.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.0ms
# image 11/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/174.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.5ms
# image 12/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/175.png: 384x640 2 lubangCobloss, 1 paslon1, 1 paslon2, 1 paslon3, 7.3ms
# image 13/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/176.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 14/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/177.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.6ms
# image 15/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/23.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.4ms
# image 16/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/29.jpg: 384x640 2 lubangCobloss, 1 paslon1, 1 paslon2, 1 paslon3, 8.5ms
# image 17/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/3.jpg: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 14.8ms
# image 18/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/32.jpg: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.0ms
# image 19/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/403.png: 384x640 2 lubangCobloss, 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 20/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/404.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.2ms
# image 21/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/405.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 22/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/406.png: 384x640 2 lubangCobloss, 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 23/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/407.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 24/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/408.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.0ms
# image 25/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/409.png: 384x640 2 lubangCobloss, 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 26/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/42.jpg: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 27/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/469.png: 384x640 2 lubangCobloss, 1 paslon1, 1 paslon2, 1 paslon3, 39.0ms
# image 28/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/470.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 8.4ms
# image 29/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/471.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 30/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/472.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 31/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/473.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 32/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/474.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.8ms
# image 33/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/475.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.9ms
# image 34/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/476.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.2ms
# image 35/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/477.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 12.0ms
# image 36/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/478.png: 384x640 1 lubangCoblos, 1 paslon1, 1 paslon2, 1 paslon3, 7.4ms
# image 37/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/479.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 9.2ms
# image 38/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/480.png: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 9.8ms
# image 39/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/481.png: 384x640 2 lubangCobloss, 1 paslon1, 1 paslon2, 1 paslon3, 7.0ms
# image 40/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095743_mp4-0110.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.5ms
# image 41/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095743_mp4-0111.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.1ms
# image 42/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0050.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 43/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0051.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 23.6ms
# image 44/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0052.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 45/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0053.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 13.8ms
# image 46/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0054.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 47/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0055.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 16.2ms
# image 48/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0056.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.1ms
# image 49/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095846_mp4-0057.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 7.3ms
# image 50/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095955_mp4-0079.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 51/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095955_mp4-0080.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 52/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095955_mp4-0081.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 6.9ms
# image 53/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095955_mp4-0082.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 8.4ms
# image 54/54 /content/gdrive/MyDrive/Skripsi Colab/Datatest/VID20250304095955_mp4-0083.jpg: 384x640 1 paslon1, 1 paslon2, 1 paslon3, 12.5ms
# Speed: 2.1ms preprocess, 9.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:54]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
import shutil

# Membuat file zip dari folder 'runs'
shutil.make_archive('SkripsiYoloV8s_50', 'zip', 'runs')
# Out:
# '/content/SkripsiYoloV8s_50.zip'
